# %% [markdown]
# <a href="https://colab.research.google.com/github/CharlaChai/COMBINE_workshop/blob/main/0_GraphBasics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Notebook Details
#
# - Create a basic graph

# %%
### Loading Packages
import networkx as nx
import matplotlib.pyplot as plt

# %%
# Create an empty undirected graph
G = nx.Graph()

# %%
# Add nodes
G.add_nodes_from(["Charla", "Connor", "Jia", "Murali", "Raeesah", "Ranul"])

# %%
# Add edges (representing friendships)
G.add_edge("Charla", "Connor")
G.add_edge("Charla", "Jia")
G.add_edge("Connor", "Jia")
G.add_edge("Charla", "Murali")
G.add_edge("Jia", "Murali")
G.add_edge("Jia", "Raeesah")
G.add_edge("Charla", "Raeesah")
G.add_edge("Murali", "Raeesah")
G.add_edge("Ranul", "Raeesah")
G.add_edge("Connor", "Ranul")

# %%
# Draw the network
nx.draw_networkx(G)
plt.show()

# %%
# Draw the network
plt.figure(figsize=(8, 6)) # Adjust figure size for better visualization

nx.draw_networkx(G)

plt.title("Social Network Example")
plt.axis('off') # Hide axes
plt.show()

# %%
# Draw the network
plt.figure(figsize=(8, 6)) # Adjust figure size for better visualization

nx.draw_networkx(G, with_labels=True, node_color='lightgreen', node_size=2000, font_size=10, font_weight='bold')

plt.title("Social Network Example")
plt.axis('off') # Hide axes
plt.show()

# %% [markdown]
# # Activity

# %% [markdown]
# ## Q1 - What happens if we have an extra unlinked node?
#
# Add yourself as an extra node without any edges and check the output!
# <!--
# G = nx.Graph()
#
# # Add nodes
# G.add_nodes_from(["Charla", "Connor", "Jia", "Murali", "Raeesah", "Ranul", "Sam"])
#
# # Add edges (representing friendships)
# G.add_edge("Charla", "Connor")
# G.add_edge("Charla", "Jia")
# G.add_edge("Connor", "Jia")
# G.add_edge("Charla", "Murali")
# G.add_edge("Jia", "Murali")
# G.add_edge("Jia", "Raeesah")
# G.add_edge("Charla", "Raeesah")
# G.add_edge("Murali", "Raeesah")
# G.add_edge("Ranul", "Raeesah")
# G.add_edge("Connor", "Ranul")
#
#
# # Draw the network
# plt.figure(figsize=(8, 6)) # Adjust figure size for better visualization
#
# nx.draw_networkx(G, with_labels=True, node_color='lightgreen', node_size=2000, font_size=10, font_weight='bold')
#
# plt.title("Social Network Example")
# plt.axis('off') # Hide axes
# plt.show()
# -->

# %% [markdown]
# ## Q2 - What happens if we have an extra edge?
#
# Add extra edges "Freya" and "Gary" without mentioningthem as nodes and check the output!
#
# <!--
# G = nx.Graph()
#
# # Add nodes
# G.add_nodes_from(["Charla", "Connor", "Jia", "Murali", "Raeesah", "Ranul"])
#
# # Add edges (representing friendships)
# G.add_edge("Charla", "Connor")
# G.add_edge("Charla", "Jia")
# G.add_edge("Connor", "Jia")
# G.add_edge("Charla", "Murali")
# G.add_edge("Jia", "Murali")
# G.add_edge("Jia", "Raeesah")
# G.add_edge("Charla", "Raeesah")
# G.add_edge("Murali", "Raeesah")
# G.add_edge("Ranul", "Raeesah")
# G.add_edge("Connor", "Ranul")
# G.add_edge("Murali", "Sam")
#
# # Draw the network
# plt.figure(figsize=(8, 6)) # Adjust figure size for better visualization
#
# nx.draw_networkx(G, with_labels=True, node_color='lightgreen', node_size=2000, font_size=10, font_weight='bold')
#
# plt.title("Social Network Example")
# plt.axis('off') # Hide axes
# plt.show()
# -->
